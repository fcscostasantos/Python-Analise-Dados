# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20190101', periods = 60, freq="D")
df = pd.DataFrame(np.random.randn(60,5), index=datas, columns = list("ABCDE"))

# %%
# Mostra as dimensões do data frame
df.shape
# Out:
# (60, 5)

# %%
df
# Out:
#                    A         B         C         D         E
# 2019-01-01 -0.275170 -0.360116  0.804167  0.052693 -0.678637
# 2019-01-02  0.319013 -1.489672  0.149785 -0.052593  0.334654
# 2019-01-03 -0.928521 -0.453489 -1.493418  1.432716  1.157777
# 2019-01-04  1.095199  1.044873 -1.474235  0.849194  1.614298
# 2019-01-05 -0.153566  0.729427  0.481177 -1.538924 -0.400087
# 2019-01-06  1.038234 -0.217097  2.224778 -1.583144 -1.275974
# 2019-01-07 -0.138665 -1.149793  0.783942  1.015667  0.213638
# 2019-01-08 -1.242068 -0.974187 -1.474338  1.220283 -0.592214
# 2019-01-09  1.881890 -1.752828 -0.131084 -1.061842  0.592867
# 2019-01-10 -0.251662  1.824615 -0.024966 -1.626553 -0.398133
# 2019-01-11  0.540921  0.407522  1.450573 -0.057802 -0.405916
# 2019-01-12  0.354967  0.349778 -0.293874  1.551016  1.033294
# 2019-01-13 -0.538531  1.632058 -0.558831  0.564893 -0.379933
# 2019-01-14 -0.455193  1.034123 -0.465841  0.345124  0.152409
# ...

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2019-01-01 -0.275170 -0.360116  0.804167  0.052693 -0.678637
# 2019-01-02  0.319013 -1.489672  0.149785 -0.052593  0.334654
# 2019-01-03 -0.928521 -0.453489 -1.493418  1.432716  1.157777

# %%
df['F'] = 1

# %%
df['G'] = range(60)

# %%
df.head(15)
# Out:
#                    A         B         C         D         E  F   G
# 2019-01-01 -0.275170 -0.360116  0.804167  0.052693 -0.678637  1   0
# 2019-01-02  0.319013 -1.489672  0.149785 -0.052593  0.334654  1   1
# 2019-01-03 -0.928521 -0.453489 -1.493418  1.432716  1.157777  1   2
# 2019-01-04  1.095199  1.044873 -1.474235  0.849194  1.614298  1   3
# 2019-01-05 -0.153566  0.729427  0.481177 -1.538924 -0.400087  1   4
# 2019-01-06  1.038234 -0.217097  2.224778 -1.583144 -1.275974  1   5
# 2019-01-07 -0.138665 -1.149793  0.783942  1.015667  0.213638  1   6
# 2019-01-08 -1.242068 -0.974187 -1.474338  1.220283 -0.592214  1   7
# 2019-01-09  1.881890 -1.752828 -0.131084 -1.061842  0.592867  1   8
# 2019-01-10 -0.251662  1.824615 -0.024966 -1.626553 -0.398133  1   9
# 2019-01-11  0.540921  0.407522  1.450573 -0.057802 -0.405916  1  10
# 2019-01-12  0.354967  0.349778 -0.293874  1.551016  1.033294  1  11
# 2019-01-13 -0.538531  1.632058 -0.558831  0.564893 -0.379933  1  12
# ...

# %%
# calculo entre elementos
df['Produto'] = df['A'] * df['B']

# %%
df.head(15)
# Out:
#                    A         B         C         D         E  F   G   Produto
# 2019-01-01 -0.275170 -0.360116  0.804167  0.052693 -0.678637  1   0  0.099093
# 2019-01-02  0.319013 -1.489672  0.149785 -0.052593  0.334654  1   1 -0.475225
# 2019-01-03 -0.928521 -0.453489 -1.493418  1.432716  1.157777  1   2  0.421074
# 2019-01-04  1.095199  1.044873 -1.474235  0.849194  1.614298  1   3  1.144344
# 2019-01-05 -0.153566  0.729427  0.481177 -1.538924 -0.400087  1   4 -0.112015
# 2019-01-06  1.038234 -0.217097  2.224778 -1.583144 -1.275974  1   5 -0.225398
# 2019-01-07 -0.138665 -1.149793  0.783942  1.015667  0.213638  1   6  0.159436
# 2019-01-08 -1.242068 -0.974187 -1.474338  1.220283 -0.592214  1   7  1.210006
# 2019-01-09  1.881890 -1.752828 -0.131084 -1.061842  0.592867  1   8 -3.298631
# 2019-01-10 -0.251662  1.824615 -0.024966 -1.626553 -0.398133  1   9 -0.459186
# 2019-01-11  0.540921  0.407522  1.450573 -0.057802 -0.405916  1  10  0.220437
# ...

# %%
df['f'] = 88

# %%
df.head(15)
# Out:
#                    A         B         C         D         E  F   G   Produto  \
# 2019-01-01 -0.275170 -0.360116  0.804167  0.052693 -0.678637  1   0  0.099093
# 2019-01-02  0.319013 -1.489672  0.149785 -0.052593  0.334654  1   1 -0.475225
# 2019-01-03 -0.928521 -0.453489 -1.493418  1.432716  1.157777  1   2  0.421074
# 2019-01-04  1.095199  1.044873 -1.474235  0.849194  1.614298  1   3  1.144344
# 2019-01-05 -0.153566  0.729427  0.481177 -1.538924 -0.400087  1   4 -0.112015
# 2019-01-06  1.038234 -0.217097  2.224778 -1.583144 -1.275974  1   5 -0.225398
# 2019-01-07 -0.138665 -1.149793  0.783942  1.015667  0.213638  1   6  0.159436
# 2019-01-08 -1.242068 -0.974187 -1.474338  1.220283 -0.592214  1   7  1.210006
# 2019-01-09  1.881890 -1.752828 -0.131084 -1.061842  0.592867  1   8 -3.298631
# 2019-01-10 -0.251662  1.824615 -0.024966 -1.626553 -0.398133  1   9 -0.459186
# 2019-01-11  0.540921  0.407522  1.450573 -0.057802 -0.405916  1  10  0.220437
# ...

# %%
# Visualizar Dados
df.head(2)
# Out:
#                    A         B         C         D         E  F  G   Produto  \
# 2019-01-01 -0.275170 -0.360116  0.804167  0.052693 -0.678637  1  0  0.099093
# 2019-01-02  0.319013 -1.489672  0.149785 -0.052593  0.334654  1  1 -0.475225
#
#              f
# 2019-01-01  88
# 2019-01-02  88

# %%
df.tail(2)
# Out:
#                    A         B         C         D         E  F   G   Produto  \
# 2019-02-28 -0.199283 -2.289036  0.151337  0.346126 -0.957559  1  58  0.456165
# 2019-03-01 -0.194761 -1.261699  0.258353  0.217153  0.425609  1  59  0.245730
#
#              f
# 2019-02-28  88
# 2019-03-01  88

# %%
# indice de dados
df.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12',
#                '2019-01-13', '2019-01-14', '2019-01-15', '2019-01-16',
#                '2019-01-17', '2019-01-18', '2019-01-19', '2019-01-20',
#                '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24',
#                '2019-01-25', '2019-01-26', '2019-01-27', '2019-01-28',
#                '2019-01-29', '2019-01-30', '2019-01-31', '2019-02-01',
#                '2019-02-02', '2019-02-03', '2019-02-04', '2019-02-05',
#                '2019-02-06', '2019-02-07', '2019-02-08', '2019-02-09',
#                '2019-02-10', '2019-02-11', '2019-02-12', '2019-02-13',
#                '2019-02-14', '2019-02-15', '2019-02-16', '2019-02-17',
#                '2019-02-18', '2019-02-19', '2019-02-20', '2019-02-21',
# ...

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'Produto', 'f'], dtype='object')

# %%
c = df.columns

# %%
c
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'Produto', 'f'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-2.75170230e-01, -3.60115910e-01,  8.04167336e-01,
#          5.26931407e-02, -6.78637347e-01,  1.00000000e+00,
#          0.00000000e+00,  9.90931776e-02,  8.80000000e+01],
#        [ 3.19013440e-01, -1.48967204e+00,  1.49784864e-01,
#         -5.25925426e-02,  3.34653538e-01,  1.00000000e+00,
#          1.00000000e+00, -4.75225401e-01,  8.80000000e+01],
#        [-9.28520793e-01, -4.53489294e-01, -1.49341823e+00,
#          1.43271634e+00,  1.15777738e+00,  1.00000000e+00,
#          2.00000000e+00,  4.21074239e-01,  8.80000000e+01],
#        [ 1.09519924e+00,  1.04487328e+00, -1.47423522e+00,
#          8.49194346e-01,  1.61429767e+00,  1.00000000e+00,
#          3.00000000e+00,  1.14434442e+00,  8.80000000e+01],
#        [-1.53566057e-01,  7.29426937e-01,  4.81176625e-01,
#         -1.53892390e+00, -4.00086508e-01,  1.00000000e+00,
#          4.00000000e+00, -1.12015219e-01,  8.80000000e+01],
#        [ 1.03823377e+00, -2.17097165e-01,  2.22477849e+00,
# ...

# %%
df.T
# Out:
#          2019-01-01  2019-01-02  2019-01-03  2019-01-04  2019-01-05  \
# A         -0.275170    0.319013   -0.928521    1.095199   -0.153566
# B         -0.360116   -1.489672   -0.453489    1.044873    0.729427
# C          0.804167    0.149785   -1.493418   -1.474235    0.481177
# D          0.052693   -0.052593    1.432716    0.849194   -1.538924
# E         -0.678637    0.334654    1.157777    1.614298   -0.400087
# F          1.000000    1.000000    1.000000    1.000000    1.000000
# G          0.000000    1.000000    2.000000    3.000000    4.000000
# Produto    0.099093   -0.475225    0.421074    1.144344   -0.112015
# f         88.000000   88.000000   88.000000   88.000000   88.000000
#
#          2019-01-06  2019-01-07  2019-01-08  2019-01-09  2019-01-10  ...  \
# A          1.038234   -0.138665   -1.242068    1.881890   -0.251662  ...
# B         -0.217097   -1.149793   -0.974187   -1.752828    1.824615  ...
# ...

# %% [markdown]
# # Combinação de Data Frames

# %%
df1 = pd.DataFrame({'A':['A0','A1','A2','A3'],
                    'B':['B0','B1','B2','B3'],
                    'C':['C0','C1','C2','C3'],
                    'D':['D0','D1','D2','D3']
                   }, 
                   index=[0,1,2,3])

# %%
df2 = pd.DataFrame({'A':['A4','A5','A6','A7'],
                    'B':['B4','B5','B6','B7'],
                    'C':['C4','C5','C6','C7'],
                    'D':['D4','D5','D6','D7']
                   }, 
                   index=[4,5,6,7])

# %%
df3 = pd.DataFrame({'A':['A8','A9','A10','A11'],
                    'B':['B8','B9','B10','B11'],
                    'C':['C8','C9','C10','C11'],
                    'D':['D8','D9','D10','D11']
                   }, 
                   index=[8,9,10,11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
frames = [df1,df2,df3]

# %%
frames
# Out:
# [    A   B   C   D
#  0  A0  B0  C0  D0
#  1  A1  B1  C1  D1
#  2  A2  B2  C2  D2
#  3  A3  B3  C3  D3,     A   B   C   D
#  4  A4  B4  C4  D4
#  5  A5  B5  C5  D5
#  6  A6  B6  C6  D6
#  7  A7  B7  C7  D7,       A    B    C    D
#  8    A8   B8   C8   D8
#  9    A9   B9   C9   D9
#  10  A10  B10  C10  D10
#  11  A11  B11  C11  D11]

# %%
type(frames)
# Out:
# list

# %%
# Concatenação de DataFrames
framesCombinados = pd.concat(frames)

# %%
framesCombinados
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
type(framesCombinados)
# Out:
# pandas.core.frame.DataFrame

# %%
# Outra forma de contenação de dataframes
framesCombinados2 = pd.concat([df1,df2,df3])

# %%
framesCombinados2
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
grupo = pd.concat([df1,df2,df3],keys=['f1','f2','f3'])

# %%
grupo
# Out:
#          A    B    C    D
# f1 0    A0   B0   C0   D0
#    1    A1   B1   C1   D1
#    2    A2   B2   C2   D2
#    3    A3   B3   C3   D3
# f2 4    A4   B4   C4   D4
#    5    A5   B5   C5   D5
#    6    A6   B6   C6   D6
#    7    A7   B7   C7   D7
# f3 8    A8   B8   C8   D8
#    9    A9   B9   C9   D9
#    10  A10  B10  C10  D10
#    11  A11  B11  C11  D11

# %%
#comando de localização
grupo.loc['f2']
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
# Outra forma de concatenar
g2 =  df1.append(df2)

# %%
g2
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
g2.append(df3)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
g4 = df1.append(df2).append(df3)

# %%
g4
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
g5 = df1.append([df2,df3])

# %%
g5
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# # Merge de Dados

# %%
#Cadastro da Loja a
cadastro_a = {'Id':['AA2930','BB4563','CC2139','DE2521','GT3462','HH1158'],
              'Nome':['Victor','Amanda','Bruna','Carlos','Ricardo','Maria'],
              'Idade':[20,35,40,54,30,27],
              'CEP':['00092-29','11111-11','2222-888','00000-999','88888-111','77777-666']
    
}
cadastro_a = pd.DataFrame(cadastro_a, columns=['Id','Nome','Idade','CEP'])
cadastro_a
# Out:
#        Id     Nome  Idade        CEP
# 0  AA2930   Victor     20   00092-29
# 1  BB4563   Amanda     35   11111-11
# 2  CC2139    Bruna     40   2222-888
# 3  DE2521   Carlos     54  00000-999
# 4  GT3462  Ricardo     30  88888-111
# 5  HH1158    Maria     27  77777-666

# %%
cadastro_b = {'Id':['CC9999','EF4488','DD9999','GT3462','HH1158'],
              'Nome':['Marcos','Patricia','Ericka','Ricardo','Maria'],
              'Idade':[19,30,22,30,27],
              'CEP':['00092-29','11111-11','1111-888','88888-111','77777-666']
    
}
cadastro_b = pd.DataFrame(cadastro_b, columns=['Id','Nome','Idade','CEP'])
cadastro_b
# Out:
#        Id      Nome  Idade        CEP
# 0  CC9999    Marcos     19   00092-29
# 1  EF4488  Patricia     30   11111-11
# 2  DD9999    Ericka     22   1111-888
# 3  GT3462   Ricardo     30  88888-111
# 4  HH1158     Maria     27  77777-666

# %%
#registros de Compras de todas as lojas
compras = {'Id':['AA2930','EF4488','CC2139','EF4488','CC9999','AA2930','HH1158','HH1158'],
           'Data':['2019-01-01','2019-01-30','2019-01-30','2019-02-01','2019-02-20','2019-03-15','2019-04-01','2019-04-10'],
           'Valor':[200,100,40,150,300,25,50,500]
    
}
compras = pd.DataFrame(compras, columns=['Id','Data','Valor'])
compras
# Out:
#        Id        Data  Valor
# 0  AA2930  2019-01-01    200
# 1  EF4488  2019-01-30    100
# 2  CC2139  2019-01-30     40
# 3  EF4488  2019-02-01    150
# 4  CC9999  2019-02-20    300
# 5  AA2930  2019-03-15     25
# 6  HH1158  2019-04-01     50
# 7  HH1158  2019-04-10    500

# %%
# pd.merge(tabela_da_esquerda, tabela_da_direita, on="coluna_coicidente",how="left|right|inner|outer")

# %%
# ?pd.merge()
# Out:
# Object `pd.merge()` not found.

# %%
pd.merge(cadastro_a,cadastro_b, on=["Id"], how="inner")
# Out:
#        Id   Nome_x  Idade_x      CEP_x   Nome_y  Idade_y      CEP_y
# 0  GT3462  Ricardo       30  88888-111  Ricardo       30  88888-111
# 1  HH1158    Maria       27  77777-666    Maria       27  77777-666

# %%
pd.merge(cadastro_a,cadastro_b[['Id','Idade','CEP']], on=["Id"], how="inner")
# Out:
#        Id     Nome  Idade_x      CEP_x  Idade_y      CEP_y
# 0  GT3462  Ricardo       30  88888-111       30  88888-111
# 1  HH1158    Maria       27  77777-666       27  77777-666

# %%
pd.merge(cadastro_a,cadastro_b[['Id','Idade','CEP']], on=["Id"], how="inner", suffixes=('_A','_B'))
# Out:
#        Id     Nome  Idade_A      CEP_A  Idade_B      CEP_B
# 0  GT3462  Ricardo       30  88888-111       30  88888-111
# 1  HH1158    Maria       27  77777-666       27  77777-666

# %%
lojas = pd.concat([cadastro_a,cadastro_b],ignore_index=True)

# %%
lojas
# Out:
#         Id      Nome  Idade        CEP
# 0   AA2930    Victor     20   00092-29
# 1   BB4563    Amanda     35   11111-11
# 2   CC2139     Bruna     40   2222-888
# 3   DE2521    Carlos     54  00000-999
# 4   GT3462   Ricardo     30  88888-111
# 5   HH1158     Maria     27  77777-666
# 6   CC9999    Marcos     19   00092-29
# 7   EF4488  Patricia     30   11111-11
# 8   DD9999    Ericka     22   1111-888
# 9   GT3462   Ricardo     30  88888-111
# 10  HH1158     Maria     27  77777-666

# %%
lojas.drop_duplicates(subset="Id")
# Out:
#        Id      Nome  Idade        CEP
# 0  AA2930    Victor     20   00092-29
# 1  BB4563    Amanda     35   11111-11
# 2  CC2139     Bruna     40   2222-888
# 3  DE2521    Carlos     54  00000-999
# 4  GT3462   Ricardo     30  88888-111
# 5  HH1158     Maria     27  77777-666
# 6  CC9999    Marcos     19   00092-29
# 7  EF4488  Patricia     30   11111-11
# 8  DD9999    Ericka     22   1111-888

# %%
#Left
pd.merge(cadastro_a,compras, on=["Id"], how="left")
# Out:
#        Id     Nome  Idade        CEP        Data  Valor
# 0  AA2930   Victor     20   00092-29  2019-01-01  200.0
# 1  AA2930   Victor     20   00092-29  2019-03-15   25.0
# 2  BB4563   Amanda     35   11111-11         NaN    NaN
# 3  CC2139    Bruna     40   2222-888  2019-01-30   40.0
# 4  DE2521   Carlos     54  00000-999         NaN    NaN
# 5  GT3462  Ricardo     30  88888-111         NaN    NaN
# 6  HH1158    Maria     27  77777-666  2019-04-01   50.0
# 7  HH1158    Maria     27  77777-666  2019-04-10  500.0

# %%
esquerda=pd.merge(cadastro_a,compras, on=["Id"], how="left")

# %%
esquerda.groupby(['Id','Nome'])['Valor'].sum()
# Out:
# Id      Nome
# AA2930  Victor     225.0
# BB4563  Amanda       0.0
# CC2139  Bruna       40.0
# DE2521  Carlos       0.0
# GT3462  Ricardo      0.0
# HH1158  Maria      550.0
# Name: Valor, dtype: float64

# %%
#Outer
pd.merge(cadastro_a,cadastro_b, on=["Id"], how="outer", indicator=True)
# Out:
#        Id   Nome_x  Idade_x      CEP_x    Nome_y  Idade_y      CEP_y  \
# 0  AA2930   Victor     20.0   00092-29       NaN      NaN        NaN
# 1  BB4563   Amanda     35.0   11111-11       NaN      NaN        NaN
# 2  CC2139    Bruna     40.0   2222-888       NaN      NaN        NaN
# 3  DE2521   Carlos     54.0  00000-999       NaN      NaN        NaN
# 4  GT3462  Ricardo     30.0  88888-111   Ricardo     30.0  88888-111
# 5  HH1158    Maria     27.0  77777-666     Maria     27.0  77777-666
# 6  CC9999      NaN      NaN        NaN    Marcos     19.0   00092-29
# 7  EF4488      NaN      NaN        NaN  Patricia     30.0   11111-11
# 8  DD9999      NaN      NaN        NaN    Ericka     22.0   1111-888
#
#        _merge
# 0   left_only
# 1   left_only
# 2   left_only
# 3   left_only
# 4        both
# 5        both
# 6  right_only
# 7  right_only
# 8  right_only

# %% [markdown]
# # Trabalhando com Group BY

# %%
df= pd.DataFrame({'A':['verdadeiro','falso','verdadeiro','falso','verdadeiro','falso','verdadeiro','falso'],
                   'B':['um','um','dois','tres','dois','dois','um','tres'],
                   'C':np.random.randn(8),
                   'D':np.random.randn(8)
    
})

# %%
df
# Out:
#             A     B         C         D
# 0  verdadeiro    um  0.853231 -0.977549
# 1       falso    um  0.832487 -0.064265
# 2  verdadeiro  dois  1.054669  1.104324
# 3       falso  tres  0.548413 -1.781921
# 4  verdadeiro  dois -1.973243  0.111896
# 5       falso  dois  1.660640 -0.530290
# 6  verdadeiro    um -0.781718  1.982830
# 7       falso  tres  0.684842 -0.103853

# %%
df.groupby(['A']).sum()
# Out:
#                    C         D
# A
# falso       3.726382 -2.480329
# verdadeiro -0.847061  2.221501

# %%
df.groupby(['A']).mean()
# Out:
#                    C         D
# A
# falso       0.931595 -0.620082
# verdadeiro -0.211765  0.555375

# %%
df.groupby(['B']).sum()
# Out:
#              C         D
# B
# dois  0.742067  0.685930
# tres  1.233254 -1.885774
# um    0.903999  0.941016

# %%
df.groupby(['A','B']).sum()
# Out:
#                         C         D
# A          B
# falso      dois  1.660640 -0.530290
#            tres  1.233254 -1.885774
#            um    0.832487 -0.064265
# verdadeiro dois -0.918573  1.216220
#            um    0.071513  1.005281

# %% [markdown]
# # Indexação

# %%
v = [22,55,7,9]

# %%
v
# Out:
# [22, 55, 7, 9]

# %%
v[2]
# Out:
# 7

# %%
v[0]
# Out:
# 22

# %%
arrays = [[1,1,2,2],['red','blue','red','blue']]

# %%
v = pd.MultiIndex.from_arrays(arrays, names=('number','color'))

# %%
v
# Out:
# MultiIndex([(1,  'red'),
#             (1, 'blue'),
#             (2,  'red'),
#             (2, 'blue')],
#            names=['number', 'color'])

# %%
numbers = [0,1,2]
colors = ['green','purple']
pd.MultiIndex.from_product([numbers,colors],names=['number','color'])
# Out:
# MultiIndex([(0,  'green'),
#             (0, 'purple'),
#             (1,  'green'),
#             (1, 'purple'),
#             (2,  'green'),
#             (2, 'purple')],
#            names=['number', 'color'])

# %% [markdown]
# # Reshaping

# %%
datas = pd.date_range('20200101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns=['Var_A','Var_B','Var_C','Var_D'])

# %%
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01  1.651951 -0.869765  0.678117  1.522575
# 2020-01-02  0.779651  1.634556  0.960119  0.365057
# 2020-01-03  0.680726  1.106629 -0.948583  1.504321
# 2020-01-04 -0.651899  0.683615  0.660774  0.854757
# 2020-01-05 -0.469927 -2.237986  0.930634 -0.032099
# 2020-01-06 -0.969332 -0.159213  1.945817  0.412643

# %%
#Transpose
dft = df.T

# %%
df.shape
# Out:
# (6, 4)

# %%
dft.shape
# Out:
# (4, 6)

# %%
np.size(dft.values)
# Out:
# 24

# %%
dft.values
# Out:
# array([[ 1.65195064,  0.77965143,  0.68072595, -0.6518994 , -0.46992735,
#         -0.96933169],
#        [-0.86976454,  1.63455557,  1.10662862,  0.68361544, -2.23798607,
#         -0.15921302],
#        [ 0.67811744,  0.96011871, -0.94858326,  0.66077434,  0.93063394,
#          1.94581669],
#        [ 1.52257521,  0.36505689,  1.5043205 ,  0.8547571 , -0.03209883,
#          0.41264307]])

# %%
v = dft.values

# %%
v.reshape((2,12))
# Out:
# array([[ 1.65195064,  0.77965143,  0.68072595, -0.6518994 , -0.46992735,
#         -0.96933169, -0.86976454,  1.63455557,  1.10662862,  0.68361544,
#         -2.23798607, -0.15921302],
#        [ 0.67811744,  0.96011871, -0.94858326,  0.66077434,  0.93063394,
#          1.94581669,  1.52257521,  0.36505689,  1.5043205 ,  0.8547571 ,
#         -0.03209883,  0.41264307]])

# %% [markdown]
# # Função Pivot

# %%
dias = pd.date_range(start='20190101', periods=12)

# %%
dias
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12'],
#               dtype='datetime64[ns]', freq='D')

# %%
Pessoa = ['George','Victor','Lucas']

# %%
np.random.choice(Pessoa)
# Out:
# 'Lucas'

# %%
Nome = []
Gasto = []
for i in range(12):
    Nome.append(np.random.choice(Pessoa))
    Gasto.append(np.round(np.random.rand()*100,2))

Nome
# Out:
# ['George',
#  'Lucas',
#  'George',
#  'Lucas',
#  'George',
#  'George',
#  'Lucas',
#  'Victor',
#  'Lucas',
#  'Lucas',
#  'Lucas',
#  'George']

# %%
Gasto
# Out:
# [92.65,
#  1.06,
#  95.35,
#  31.93,
#  57.18,
#  13.17,
#  63.36,
#  25.63,
#  70.4,
#  35.18,
#  52.01,
#  73.78]

# %%
df = pd.DataFrame({'Dia':dias, 'Nome':Nome,'Gasto':Gasto})

# %%
df
# Out:
#           Dia    Nome  Gasto
# 0  2019-01-01  George  92.65
# 1  2019-01-02   Lucas   1.06
# 2  2019-01-03  George  95.35
# 3  2019-01-04   Lucas  31.93
# 4  2019-01-05  George  57.18
# 5  2019-01-06  George  13.17
# 6  2019-01-07   Lucas  63.36
# 7  2019-01-08  Victor  25.63
# 8  2019-01-09   Lucas  70.40
# 9  2019-01-10   Lucas  35.18
# 10 2019-01-11   Lucas  52.01
# 11 2019-01-12  George  73.78

# %%
# uma forma de transpor as informações
df.pivot(index='Dia',columns='Nome',values='Gasto')
# Out:
# Nome        George  Lucas  Victor
# Dia
# 2019-01-01   92.65    NaN     NaN
# 2019-01-02     NaN   1.06     NaN
# 2019-01-03   95.35    NaN     NaN
# 2019-01-04     NaN  31.93     NaN
# 2019-01-05   57.18    NaN     NaN
# 2019-01-06   13.17    NaN     NaN
# 2019-01-07     NaN  63.36     NaN
# 2019-01-08     NaN    NaN   25.63
# 2019-01-09     NaN  70.40     NaN
# 2019-01-10     NaN  35.18     NaN
# 2019-01-11     NaN  52.01     NaN
# 2019-01-12   73.78    NaN     NaN

# %% [markdown]
# # Pivot Table

# %%
Carros = [7,4,3,2,8]
dias = pd.date_range('20190101','20190101',periods=5)
vendedor = ['George','Vagner','Pedro','Vagner','George']

df = pd.DataFrame({'Vendas':Carros,'Data':dias,'Vendedor':vendedor})

# %%
df
# Out:
#    Vendas       Data Vendedor
# 0       7 2019-01-01   George
# 1       4 2019-01-01   Vagner
# 2       3 2019-01-01    Pedro
# 3       2 2019-01-01   Vagner
# 4       8 2019-01-01   George

# %%
pd.pivot(df,index='Data',columns='Vendedor',values='Vendas')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-d0d9281861bb> in <module>
# ----> 1 pd.pivot(df,index='Data',columns='Vendedor',values='Vendas')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     428         else:
#     429             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 430     return indexed.unstack(columns)
#     431
#     432
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    3743         from pandas.core.reshape.reshape import unstack
#    3744
# -> 3745         return unstack(self, level, fill_value)
#    3746
#    3747     # ----------------------------------------------------------------------
#
# ...

# %%
pd.pivot_table(df,index='Data',columns='Vendedor',values='Vendas', aggfunc='sum')
# Out:
# Vendedor    George  Pedro  Vagner
# Data
# 2019-01-01      15      3       6

# %% [markdown]
# # Stack Instack

# %%
df = pd.read_csv("https://cdncontribute.geeksforgeeks.org/wp-content/uploads/nba.csv")

# %%
df.head(4)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0

# %%
df.shape
# Out:
# (458, 9)

# %%
stack_df = df.stack()

# %%
stack_df
# Out:
# 0    Name         Avery Bradley
#      Team        Boston Celtics
#      Number                   0
#      Position                PG
#      Age                     25
#                       ...
# 456  Age                     26
#      Height                 7-0
#      Weight                 231
#      College             Kansas
#      Salary              947276
# Length: 4018, dtype: object

# %%
udf = stack_df.unstack()

# %%
udf
# Out:
#               Name            Team Number Position Age Height Weight  \
# 0    Avery Bradley  Boston Celtics      0       PG  25    6-2    180
# 1      Jae Crowder  Boston Celtics     99       SF  25    6-6    235
# 2     John Holland  Boston Celtics     30       SG  27    6-5    205
# 3      R.J. Hunter  Boston Celtics     28       SG  22    6-5    185
# 4    Jonas Jerebko  Boston Celtics      8       PF  29   6-10    231
# ..             ...             ...    ...      ...  ..    ...    ...
# 452     Trey Lyles       Utah Jazz     41       PF  20   6-10    234
# 453   Shelvin Mack       Utah Jazz      8       PG  26    6-3    203
# 454      Raul Neto       Utah Jazz     25       PG  24    6-1    179
# 455   Tibor Pleiss       Utah Jazz     21        C  26    7-3    256
# 456    Jeff Withey       Utah Jazz     24        C  26    7-0    231
#
#                College       Salary
# 0                Texas  7.73034e+06
# 1            Marquette  6.79612e+06
# ...

# %% [markdown]
# # Função Melt

# %%
df = pd.DataFrame({'A':{0:'a',1:'b',2:'c'},
                   'B':{0: 1, 1: 3, 2: 5},
                   'C':{0: 2, 1: 4, 2: 6}
                  })

# %%
df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
pd.melt(df, id_vars=['A'], value_vars=['B'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5

# %%
pd.melt(df, id_vars=['A'], value_vars=['B','C'], var_name='VarTeste',value_name='Nome do Valor')
# Out:
#    A VarTeste  Nome do Valor
# 0  a        B              1
# 1  b        B              3
# 2  c        B              5
# 3  a        C              2
# 4  b        C              4
# 5  c        C              6

# %%
data = {
    "localizacao":['CidadeA', 'CidadeB'],
    "Temperatura":['Prevista', 'Atual'],
    "Set-2019":[30, 32],
    "Out-2019":[45, 43],
    "Nov-2019":[24, 22]
}

print(data)
# Out:
# {'localizacao': ['CidadeA', 'CidadeB'], 'Temperatura': ['Prevista', 'Atual'], 'Set-2019': [30, 32], 'Out-2019': [45, 43], 'Nov-2019': [24, 22]}

# %%
df = pd.DataFrame(data, columns=["localizacao","Temperatura","Set-2019","Out-2019","Nov-2019"])
print(df)
# Out:
#   localizacao Temperatura  Set-2019  Out-2019  Nov-2019
# 0     CidadeA    Prevista        30        45        24
# 1     CidadeB       Atual        32        43        22

# %%
dtf2 = pd.melt(df, id_vars=["localizacao","Temperatura"], var_name="Date", value_name="Value")
print(dtf2)
# Out:
#   localizacao Temperatura      Date  Value
# 0     CidadeA    Prevista  Set-2019     30
# 1     CidadeB       Atual  Set-2019     32
# 2     CidadeA    Prevista  Out-2019     45
# 3     CidadeB       Atual  Out-2019     43
# 4     CidadeA    Prevista  Nov-2019     24
# 5     CidadeB       Atual  Nov-2019     22

# %%
dtf2 = pd.melt(df, id_vars=["localizacao"], var_name="Date", value_name="Value")
print(dtf2)
# Out:
#   localizacao         Date     Value
# 0     CidadeA  Temperatura  Prevista
# 1     CidadeB  Temperatura     Atual
# 2     CidadeA     Set-2019        30
# 3     CidadeB     Set-2019        32
# 4     CidadeA     Out-2019        45
# 5     CidadeB     Out-2019        43
# 6     CidadeA     Nov-2019        24
# 7     CidadeB     Nov-2019        22

# %% [markdown]
# # Seleção dos Dados

# %%
datas = pd.date_range('20180101', periods = 600, freq="D")
df = pd.DataFrame(np.random.randn(600,5), index = datas, columns = list("ABCDE"))

# %%
df.head(5)
# Out:
#                    A         B         C         D         E
# 2018-01-01  0.854521 -0.734027  0.485662 -0.058860 -0.089352
# 2018-01-02 -0.964370  0.952596 -0.062765  1.765303 -1.264449
# 2018-01-03 -1.319944 -2.001110  1.176502 -0.313038  0.183655
# 2018-01-04 -0.033964 -0.018461  0.012013  0.819211 -0.186107
# 2018-01-05 -0.638578  0.366636  0.293542  1.267335  0.379934

# %%
df['D'].head(5)
# Out:
# 2018-01-01   -0.058860
# 2018-01-02    1.765303
# 2018-01-03   -0.313038
# 2018-01-04    0.819211
# 2018-01-05    1.267335
# Freq: D, Name: D, dtype: float64

# %%
df.head(10)
# Out:
#                    A         B         C         D         E
# 2018-01-01  0.854521 -0.734027  0.485662 -0.058860 -0.089352
# 2018-01-02 -0.964370  0.952596 -0.062765  1.765303 -1.264449
# 2018-01-03 -1.319944 -2.001110  1.176502 -0.313038  0.183655
# 2018-01-04 -0.033964 -0.018461  0.012013  0.819211 -0.186107
# 2018-01-05 -0.638578  0.366636  0.293542  1.267335  0.379934
# 2018-01-06 -0.984847  0.869459  0.346419  0.719905 -1.371376
# 2018-01-07 -0.567881  0.216430 -1.637765  0.521617  0.613812
# 2018-01-08 -0.533584  1.107600  0.567473 -0.075548 -0.123016
# 2018-01-09  2.222683  0.564632  2.004828 -0.810353 -0.795201
# 2018-01-10  1.723478 -0.840266 -0.062539 -1.306641 -0.803800

# %%
df[1:5]
# Out:
#                    A         B         C         D         E
# 2018-01-02 -0.964370  0.952596 -0.062765  1.765303 -1.264449
# 2018-01-03 -1.319944 -2.001110  1.176502 -0.313038  0.183655
# 2018-01-04 -0.033964 -0.018461  0.012013  0.819211 -0.186107
# 2018-01-05 -0.638578  0.366636  0.293542  1.267335  0.379934

# %%
df.loc[:,['B','C','D']]
# Out:
#                    B         C         D
# 2018-01-01 -0.734027  0.485662 -0.058860
# 2018-01-02  0.952596 -0.062765  1.765303
# 2018-01-03 -2.001110  1.176502 -0.313038
# 2018-01-04 -0.018461  0.012013  0.819211
# 2018-01-05  0.366636  0.293542  1.267335
# ...              ...       ...       ...
# 2019-08-19 -0.816466 -1.503743  1.562980
# 2019-08-20 -0.687907 -1.687932 -2.046022
# 2019-08-21  0.052956  0.025141  0.141639
# 2019-08-22  2.328214 -0.651559  0.362350
# 2019-08-23  0.685629  1.200272 -0.004701
#
# [600 rows x 3 columns]

# %%
f = df.loc['20180301':'20180917',['A','E']].head(5)

# %%
len(f)
# Out:
# 5

# %%
df.iloc[2:4, 0:2]
# Out:
#                    A         B
# 2018-01-03 -1.319944 -2.001110
# 2018-01-04 -0.033964 -0.018461

# %%
df.iloc[[1,5,6],[0,3]]
# Out:
#                    A         D
# 2018-01-02 -0.964370  1.765303
# 2018-01-06 -0.984847  0.719905
# 2018-01-07 -0.567881  0.521617

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D         E
# 2018-01-02 -0.964370  0.952596 -0.062765  1.765303 -1.264449
# 2018-01-03 -1.319944 -2.001110  1.176502 -0.313038  0.183655
